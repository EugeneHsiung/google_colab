# %% [markdown]
# <a href="https://colab.research.google.com/github/EugeneHsiung/google_colab/blob/main/hha507class1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Loading Packages

# %%
import pandas as pd
import seaborn as sns
import plotly as pit

# %%
# !pip freeze > packages.txt

# %% [markdown]
# #Creating Functions

# %%
def bloodpress(systolic, diastolic):
  total = systolic + diastolic
  return total

# %%
def bloodsugar(value):
  valuetoprint = f"Your blood sugar is {value}"
  return valuetoprint

# %% [markdown]
# # Testing Functions

# %%
# Test for Blood Pressure
test1 = bloodpress (190, 155)
test1
# Out:
# 345

# %%
test2 = bloodsugar (200)
print(test2)
# Out:
# Your blood sugar is 200

# %% [markdown]
# # Pandas data loading

# %%
## Loading in the file first
df = pd.read_csv('https://raw.githubusercontent.com/hantswilliams/HHA_504_2023/main/WK1/data/113243405_StonyBrookEasternLongIslandHospital_standardcharges.csv')

# %%
df
# Out:
#        Code                                        Description        Type  \
# 0     10060          SIMPLE OR SINGLE DRAINAGE OF SKIN ABSCESS  Outpatient
# 1     10060          SIMPLE OR SINGLE DRAINAGE OF SKIN ABSCESS  Outpatient
# 2     10080                SIMPLE DRAINAGE OF CYST OF TAILBONE  Outpatient
# 3     10080                SIMPLE DRAINAGE OF CYST OF TAILBONE  Outpatient
# 4     10120  REMOVAL OF FOREIGN BODY FROM TISSUE, ACCESSED ...  Outpatient
# ...     ...                                                ...         ...
# 2983  U0002                                     SARS COV 2 RNA         NaN
# 2984  V2632                                  INTRAOCCULAR LENS         NaN
# 2985  V2632                                       PANOPTIX IOL         NaN
# 2986  V2785                                      CORNEAL GRAFT         NaN
# 2987  V2790                                        AMBIO DRY 2         NaN
#
#      Package/Line_Level  Gross charge  Discounted cash price  \
# 0                  Line        575.75                 575.75
# 1               Package        575.75                 575.75
# 2                  Line        548.00                 548.00
# 3               Package       7675.00                7675.00
# 4                  Line        487.00                 487.00
# ...                 ...           ...                    ...
# 2983                NaN        518.95                    NaN
# 2984                NaN       1696.10                    NaN
# 2985                NaN       2985.00                    NaN
# 2986                NaN      16388.10                    NaN
# 2987                NaN       2211.00                    NaN
#
#       De-identified min contracted rate  De-identified max contracted rate  \
# 0                                384.69                             786.90
# 1                                384.69                             786.90
# 2                                   NaN                                NaN
# 3                                   NaN                                NaN
# 4                                371.66                             371.66
# ...                                 ...                                ...
# 2983                                NaN                                NaN
# 2984                                NaN                                NaN
# 2985                                NaN                                NaN
# 2986                                NaN                                NaN
# 2987                                NaN                                NaN
#
#       Derived contracted rate  AETNA-Commercial HMO/POS  ...  \
# 0                      585.80                       NaN  ...
# 1                      585.80                       NaN  ...
# 2                         NaN                       NaN  ...
# 3                         NaN                       NaN  ...
# 4                      371.66                       NaN  ...
# ...                       ...                       ...  ...
# 2983                      NaN                       NaN  ...
# 2984                      NaN                       NaN  ...
# 2985                      NaN                       NaN  ...
# 2986                      NaN                       NaN  ...
# 2987                      NaN                       NaN  ...
#
#       HandM-Commercial HMO/POS  HEALTHFIRST-Commercial HMO/POS  \
# 0                          NaN                          384.69
# 1                          NaN                          384.69
# 2                          NaN                             NaN
# 3                          NaN                             NaN
# 4                          NaN                          371.66
# ...                        ...                             ...
# 2983                       NaN                             NaN
# 2984                       NaN                             NaN
# 2985                       NaN                             NaN
# 2986                       NaN                             NaN
# 2987                       NaN                             NaN
#
#       BLUE CROSS-Medicaid HMO  UNITED HEALTHCARE-Commercial HMO/POS  \
# 0                         NaN                                   NaN
# 1                         NaN                                   NaN
# 2                         NaN                                   NaN
# 3                         NaN                                   NaN
# 4                         NaN                                   NaN
# ...                       ...                                   ...
# 2983                      NaN                                   NaN
# 2984                      NaN                                   NaN
# 2985                      NaN                                   NaN
# 2986                      NaN                                   NaN
# 2987                      NaN                                   NaN
#
#       UNITED HEALTHCARE-Medicare Advantage HMO  \
# 0                                          NaN
# 1                                          NaN
# 2                                          NaN
# 3                                          NaN
# 4                                          NaN
# ...                                        ...
# 2983                                       NaN
# 2984                                       NaN
# 2985                                       NaN
# 2986                                       NaN
# 2987                                       NaN
#
#       INTEGRATED HEALTH-Commercial HMO/POS  MOLINA-Medicaid HMO  \
# 0                                      NaN                  NaN
# 1                                      NaN                  NaN
# 2                                      NaN                  NaN
# 3                                      NaN                  NaN
# 4                                      NaN                  NaN
# ...                                    ...                  ...
# 2983                                   NaN                  NaN
# 2984                                   NaN                  NaN
# 2985                                   NaN                  NaN
# 2986                                   NaN                  NaN
# 2987                                   NaN                  NaN
#
#       TUFTS HEALTH-Commercial HMO/POS  \
# 0                                 NaN
# 1                                 NaN
# 2                                 NaN
# 3                                 NaN
# 4                                 NaN
# ...                               ...
# 2983                              NaN
# 2984                              NaN
# 2985                              NaN
# 2986                              NaN
# 2987                              NaN
#
#       UNITED HEALTHCARE-Commercial PPO/Open Access  \
# 0                                              NaN
# 1                                              NaN
# 2                                              NaN
# 3                                              NaN
# 4                                              NaN
# ...                                            ...
# 2983                                           NaN
# 2984                                           NaN
# 2985                                           NaN
# 2986                                           NaN
# 2987                                           NaN
#
#       UNITED HEALTHCARE-Medicaid HMO
# 0                                NaN
# 1                                NaN
# 2                                NaN
# 3                                NaN
# 4                                NaN
# ...                              ...
# 2983                             NaN
# 2984                             NaN
# 2985                             NaN
# 2986                             NaN
# 2987                             NaN
#
# [2988 rows x 29 columns]

# %% [markdown]
# # Example 2 of loading CSV

# %%
cancer = pd.read_csv('data-cancer-deaths.csv')

# %%
cancer
# Out:
#    Years  Historical Data  Target
# 0   2011            191.0     0.0
# 1   2012            189.9     0.0
# 2   2013            185.7     0.0
# 3   2014              0.0     0.0
# 4   2015              0.0     0.0
# 5   2016              0.0     0.0
# 6   2017              0.0     0.0
# 7   2018              0.0     0.0
# 8   2019              0.0   180.3

# %%
cancer.columns
# Out:
# Index(['Years', 'Historical Data', 'Target'], dtype='object')

# %%
cancer['Years'].sum()
# Out:
# 18135
